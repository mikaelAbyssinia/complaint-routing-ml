# %%
from complaint_routing_ml import  ROOT, ensure_project_dirs
 
print(ROOT)
ensure_project_dirs()
# Out:
# /Users/mikael_abyssinia/complaint-routing-ml

# %%
from complaint_routing_ml import DOCS_DIR, ensure_project_dirs
 
print(DOCS_DIR)
ensure_project_dirs()
# Out:
# /Users/mikael_abyssinia/complaint-routing-ml/docs

# %%
print(ROOT)
# Out:
# /Users/mikael_abyssinia/complaint-routing-ml

# %%
ensure_project_dirs(
